# %%
# Data Visualization Techniques Lab
## Experiment 1
### Jupyter Notebook Basics

# %%
# Program 1 & 2: Testing Python Execution
print("Welcome to Data Analytics Lab")

a, b = 20, 10
print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
# Out:
# Welcome to Data Analytics Lab
# Addition = 30
# Subtraction = 10
# Multiplication = 200
# Division = 2.0

# %%
# Program 5 & 7: Library Test
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

a = np.array([10, 20, 30, 40, 50])
print("NumPy Array:", a)
print("Mean =", np.mean(a))

plt.plot([1, 2, 3, 4, 5], [10, 20, 15, 25, 30])
plt.title("Sample Line Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()
# Out:
# NumPy Array: [10 20 30 40 50]
# Mean = 30.0
